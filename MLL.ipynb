# %% [markdown]
# <a href="https://colab.research.google.com/github/Anjali98765/Internshipstudio/blob/master/MLL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Project Title: Marketing Campaign for Banking Products**
#
# **Description About Project:**
# The retail marketing department to devise campaigns with better marketing to increase the success ratio with minimal budget.The department wants to build a model that will help them identitfy the potential customers who have higher probability of purchasing the loan.This will increase the success ratio while at the same time reduce the cost of the campaign.
#
# The dataset contains data on 5000 customers.
#
# The case is The Bank has a customers Data with various characteristics of the customers.The management built a new product-Personal Loan,and ran a small campaign towards selling the New Product to their clients.After some time,9% of customers have Personal Loan from the Bank.
#
# **The GOAL is!**
#
# *    To sell more Personal Loan to Bank Customers.
#
# *   To devise campaigns to better target marketing to increase the success ratio with a minimal budget.
#
#
# *   To identify the potential customers who have a higher probability of purchasing the loan.
#
# Increase the success ratio of advertisement campaign while at the same time reduce the cost of the campaign.

# %% [markdown]
# **1**. **Importing the Required libraries and the dataset.**

# %%
#importing Libraries
import numpy as np         #used for multidimensional array
import pandas as pd        #used for import the dataset
import seaborn as sns      #used for data visualization
import matplotlib.pyplot as plt     #used for plot the graph
# %matplotlib inline
sns.set()

# %%
#Loading the dataset
data=pd.read_csv('Bank_Personal_Loan_Modelling.csv')

# %%
#Checking all columns in the dataset
data.columns
# Out:
# Index(['ID', 'Age', 'Experience', 'Income', 'ZIP Code', 'Family', 'CCAvg',
#        'Education', 'Mortgage', 'Personal Loan', 'Securities Account',
#        'CD Account', 'Online', 'CreditCard'],
#       dtype='object')

# %% [markdown]
# **There are 12 Features** :
#
#  **ID:** Customers ID.
#
#  **Age:** Customers age.
#
#  **Experience:** Number of years of the customer.
#
#  **Income:** Annual income of the customer.
#
#  **ZIP Code:** Home Address ZIP Code.
#
#  **Family:** Family size of the customer.
#
#  **CCAvg:** Average spending on credit cards per month.
#
#  **Education:** Education level 1.Undergrad;2.Graduate;3.Advanced Professional.
#
#  **Mortgage:** Value of house mortgage if any.
#
#  **Secuities Account:** Does the customer have a securities account with the bank?
#
#  **CD Account:** Does the customer have a certificate of deposit(CD) account with the bank?
#
#  **Online:** Does the customeruse internet banking facilities.
#
#  **CreditCard:** Does the customer uses a credit card issued by UniversalBank?
#
# **Personal Loan:** Did this customer accept the personal loan offered in the last campaign?

# %% [markdown]
# **Binary Category are:**
#
# 1.Personal Loan
# 2.Securities Account
# 3.CD Account
# 4.Online
# 5.Credit Card
#
#
# **Internal Variables are:**
#
# 1.Age
# 2.Experience
# 3.Income
# 4.CCAvg
# 5.Mortgage
#
# **Ordinal Category are:**
#
# 1.Family
# 2.Education
#
# **Nominal Category are:**
#
# 1.ID
# 2.ZIP Code

# %%
#To display top 5 values of dataset
data.head()
# Out:
#    ID  Age  Experience  ...  CD Account  Online  CreditCard
# 0   1   25           1  ...           0       0           0
# 1   2   45          19  ...           0       0           0
# 2   3   39          15  ...           0       0           0
# 3   4   35           9  ...           0       0           0
# 4   5   35           8  ...           0       0           1
#
# [5 rows x 14 columns]

# %%
#To display bottom 5 values of dataset
data.tail()
# Out:
#         ID  Age  Experience  ...  CD Account  Online  CreditCard
# 4995  4996   29           3  ...           0       1           0
# 4996  4997   30           4  ...           0       1           0
# 4997  4998   63          39  ...           0       0           0
# 4998  4999   65          40  ...           0       1           0
# 4999  5000   28           4  ...           0       1           1
#
# [5 rows x 14 columns]

# %% [markdown]
# **2.Checking Datatype,statiscal Summary,Shape,null values**

# %%
#Displaying datatypes of each column
data.dtypes
# Out:
# ID                      int64
# Age                     int64
# Experience              int64
# Income                  int64
# ZIP Code                int64
# Family                  int64
# CCAvg                 float64
# Education               int64
# Mortgage                int64
# Personal Loan           int64
# Securities Account      int64
# CD Account              int64
# Online                  int64
# CreditCard              int64
# dtype: object

# %%
#Displaying if any nonnull value in each column
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  5000 non-null   int64
#  1   Age                 5000 non-null   int64
#  2   Experience          5000 non-null   int64
#  3   Income              5000 non-null   int64
#  4   ZIP Code            5000 non-null   int64
#  5   Family              5000 non-null   int64
#  6   CCAvg               5000 non-null   float64
#  7   Education           5000 non-null   int64
#  8   Mortgage            5000 non-null   int64
#  9   Personal Loan       5000 non-null   int64
#  10  Securities Account  5000 non-null   int64
#  11  CD Account          5000 non-null   int64
#  12  Online              5000 non-null   int64
#  13  CreditCard          5000 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 547.0 KB

# %%
#To display total rows and columns in dataset
data.shape
# Out:
# (5000, 14)

# %%
#To display the summary stats of dataset
data.describe()
# Out:
#                 ID          Age  ...       Online   CreditCard
# count  5000.000000  5000.000000  ...  5000.000000  5000.000000
# mean   2500.500000    45.338400  ...     0.596800     0.294000
# std    1443.520003    11.463166  ...     0.490589     0.455637
# min       1.000000    23.000000  ...     0.000000     0.000000
# 25%    1250.750000    35.000000  ...     0.000000     0.000000
# 50%    2500.500000    45.000000  ...     1.000000     0.000000
# 75%    3750.250000    55.000000  ...     1.000000     1.000000
# max    5000.000000    67.000000  ...     1.000000     1.000000
#
# [8 rows x 14 columns]

# %%
data.describe().transpose()
# Out:
#                      count          mean  ...       75%      max
# ID                  5000.0   2500.500000  ...   3750.25   5000.0
# Age                 5000.0     45.338400  ...     55.00     67.0
# Experience          5000.0     20.104600  ...     30.00     43.0
# Income              5000.0     73.774200  ...     98.00    224.0
# ZIP Code            5000.0  93152.503000  ...  94608.00  96651.0
# Family              5000.0      2.396400  ...      3.00      4.0
# CCAvg               5000.0      1.937938  ...      2.50     10.0
# Education           5000.0      1.881000  ...      3.00      3.0
# Mortgage            5000.0     56.498800  ...    101.00    635.0
# Personal Loan       5000.0      0.096000  ...      0.00      1.0
# Securities Account  5000.0      0.104400  ...      0.00      1.0
# CD Account          5000.0      0.060400  ...      0.00      1.0
# Online              5000.0      0.596800  ...      1.00      1.0
# ...

# %% [markdown]
# **Observation:**
#
#         1. Column "Experience" has some negative value. Need to fix
#         2. Binary variables "Personal Loan", "CreditCard", "Online", "CD Account", "Securities Account" has clean data
#         3. Ordinary Categorical variables "Family" and "Education" are clean too

# %%
#To check null value if any any in each column
data.isnull().sum()
# Out:
# ID                    0
# Age                   0
# Experience            0
# Income                0
# ZIP Code              0
# Family                0
# CCAvg                 0
# Education             0
# Mortgage              0
# Personal Loan         0
# Securities Account    0
# CD Account            0
# Online                0
# CreditCard            0
# dtype: int64

# %%
#Checking correlation between age and experience.
exp = data['Experience']
age = data['Age']
correlation = exp.corr(age)
correlation
# Out:
# 0.9942148569683321

# %% [markdown]
# **Observation:**  Age and Experience are highly correlated.
#                   (This means Change in age results change in experience and viceversa)

# %%
#Checking correlation between income and CCAvg 
inc = data['Income']
ccavg = data['CCAvg']
correlation = inc.corr(ccavg)
correlation
# Out:
# 0.6459836696249653

# %% [markdown]
# **Observation:** Income and CCAvg are not highly correlated.

# %%
inc = data['Income']
zz = data['ZIP Code']
correlation = inc.corr(zz)
correlation
# Out:
# -0.016409811655448938

# %%
#Droping ID And Experience
data = data.drop(['ID','Experience'],axis=1)
data.head()
# Out:
#    Age  Income  ZIP Code  ...  CD Account  Online  CreditCard
# 0   25      49     91107  ...           0       0           0
# 1   45      34     90089  ...           0       0           0
# 2   39      11     94720  ...           0       0           0
# 3   35     100     94112  ...           0       0           0
# 4   35      45     91330  ...           0       0           1
#
# [5 rows x 12 columns]

# %% [markdown]
# **Observation:** ID is Categorical nominal data and thus has 5000 unique values and hence droping it will help in predicting our dataset better.
# Experience is highly correlated with age and hence, we can have only one feature out of both.

# %%
#Checking Unique values in ZIP Code column.
data['ZIP Code'].nunique()
# Out:
# 467

# %%
#Dropping ZIP Code
data = data.drop(['ZIP Code'],axis=1)
data.head()
# Out:
#    Age  Income  Family  ...  CD Account  Online  CreditCard
# 0   25      49       4  ...           0       0           0
# 1   45      34       3  ...           0       0           0
# 2   39      11       1  ...           0       0           0
# 3   35     100       1  ...           0       0           0
# 4   35      45       4  ...           0       0           1
#
# [5 rows x 11 columns]

# %% [markdown]
# **Observation:** ZIP Code is categorical nominal data and has 467 unique values hence dropping it will predict our model better.

# %%
#To display duplicates
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4995    False
# 4996    False
# 4997    False
# 4998    False
# 4999    False
# Length: 5000, dtype: bool

# %%
#Total duplicate values
data.duplicated().sum()
# Out:
# 13

# %%
duplicate_rows_dataset = data[data.duplicated()]
print("Number of duplicate rows ", duplicate_rows_dataset)
# Out:
# Number of duplicate rows        Age  Income  Family  ...  CD Account  Online  CreditCard
# 799    29      39       4  ...           0       1           0
# 1026   28      43       3  ...           0       1           0
# 1526   36      80       4  ...           0       1           0
# 2031   60      80       3  ...           0       1           0
# 2806   53      59       2  ...           0       1           0
# 3050   50      58       1  ...           0       1           0
# 3453   29      31       4  ...           0       1           0
# 3694   38      21       1  ...           0       1           0
# 4058   39      65       1  ...           0       0           0
# 4482   40      28       2  ...           0       0           0
# 4616   66     114       1  ...           0       1           1
# 4744   44      72       3  ...           0       1           0
# 4746   31      18       1  ...           0       1           0
#
# [13 rows x 11 columns]

# %%
#To drop duplicates
data.drop_duplicates()
# Out:
#       Age  Income  Family  ...  CD Account  Online  CreditCard
# 0      25      49       4  ...           0       0           0
# 1      45      34       3  ...           0       0           0
# 2      39      11       1  ...           0       0           0
# 3      35     100       1  ...           0       0           0
# 4      35      45       4  ...           0       0           1
# ...   ...     ...     ...  ...         ...     ...         ...
# 4995   29      40       1  ...           0       1           0
# 4996   30      15       4  ...           0       1           0
# 4997   63      24       2  ...           0       0           0
# 4998   65      49       3  ...           0       1           0
# 4999   28      83       3  ...           0       1           1
#
# [4987 rows x 11 columns]

# %% [markdown]
# **Observation:** Droping all Duplicate Values in the dataset.

# %% [markdown]
# **3. Exploratory Data Analysis**

# %%
#To Calculate number of customers with zero/don't have any mortgage.
data[data['Mortgage']==0]['Mortgage'].count()
# Out:
# 3462

# %% [markdown]
# **Observation:** Count= 3462 tells us that many customers don't have any mortgage.

# %%
#To calculate number of customers with zero credit card spending per month.
data[data['CCAvg'] == 0]['CCAvg'].count()
# Out:
# 106

# %% [markdown]
# **Observation:** Count= 106 tells us that customers which not spend money on credit card

# %%
data[data['Securities Account'] == 0]['Securities Account'].count()
# Out:
# 4478

# %% [markdown]
# **Observation:** Count= 4478 tells us that many customers don't have any Securities Acc with bank.

# %%
data[data['CreditCard'] == 0]['CreditCard'].count()
# Out:
# 3530

# %% [markdown]
# **Observation:** Count= 3530 tells us that many customers don't have use credit card issued by the bank

# %% [markdown]
# **3.1 Univariate Analysis**

# %%
#Feature - Age
sns.distplot(data['Age'], hist=False, bins=10);

# %%
sns.boxplot(data['Age'],orient="v")

# %% [markdown]
# **Observation:** There aren't any outliers for Age feature.

# %%
# Feature -Income
sns.distplot(data['Income'], hist=False, bins=10);

# %%
sns.boxplot(data['Income'],orient="v");

# %% [markdown]
# **Observation:** From the above 2 distribution of Income feature is highly *skewed*

# %%
#Feature - Family
sns.distplot(data['Family'], hist=False, bins=10);

# %%
sns.boxplot(data['Family'],orient='v')

# %% [markdown]
# **Observation:** From above 2 Distribution their is no outlier's in Family Feature.

# %%
#Feature-CCAvg
sns.distplot(data['CCAvg'], hist=False, bins=10);

# %%
sns.boxplot(data['CCAvg'],orient='v')

# %% [markdown]
# **Observation:** CCAvg is also log-normal.

# %%
#Feature - Education
sns.distplot(data['Education'], hist=False, bins=10);

# %%
sns.boxplot(data['Education'],orient="v")

# %% [markdown]
# **Observation:** There aren't any outliers for Education feature.

# %%
#Feature - Mortgage
sns.distplot(data['Mortgage'], hist=False, bins=10);

# %%
sns.boxplot(data['Mortgage'],orient="v")

# %% [markdown]
# **Observation:**  A lot of customers doesn't have mortgage and the right side of the distribution is almost flat. We can construct an ordinal categorical feature Mortgage_Int using Mortgage feature. Then we drop Mortgage feature. We apply the same procedure to also test_x.

# %%
#Feature- Securities Account
sns.distplot(data['Securities Account'], hist=False, bins=10);

# %%
sns.boxplot(data['Securities Account'],orient="v")

# %% [markdown]
# **Observation** Froom above Distribution,A customer may have a security account or not. Securities Account is a binary categorical feature and there is no need to make outlier analysis.

# %%
#Feature - CD Account
sns.distplot(data['CD Account'], hist=False, bins=10);

# %%
sns.boxplot(data['CD Account'],orient="v")

# %% [markdown]
# **Observation:** A customer may have a CD account or not. CD Account is a binary categorical feature and there is no need to make outlier analysis.

# %%
#Feature -Online
sns.distplot(data['Online'], hist=False, bins=10);

# %%
sns.boxplot(data['Online'],orient="v")

# %% [markdown]
# **Observation:** A customer may use internet banking or not. Online is a binary categorical feature and there is no need to make outlier analysis.

# %%
#Feature - CreditCard
sns.distplot(data['CreditCard'], hist=False, bins=10);

# %%
sns.boxplot(data['CreditCard'],orient="v")

# %% [markdown]
# **Observation:** A customer may have credit card or not. CreditCard is a binary categorical feature and there is no need to make outlier analysis.

# %%
sns.countplot(data.Family)

# %% [markdown]
# **Observation:** From above plot, Customers with having only one family member has highest value.

# %%
sns.countplot(data.Education)

# %% [markdown]
# **Observation:** From above plot Customers with undergrad are high in number.

# %% [markdown]
# **3.2 Multivariate Analysis**

# %%
#Visualizing boxplot between Income and Education.
sns.boxplot(x='Education',y='Income',hue ='Personal Loan',data=data,color='blue')

# %% [markdown]
# **Observation:** Customers with High Income and Eduaction has high probability of purchasing loan.

# %%
#Visualizing boxplot between Income and Securities Account.
sns.boxplot(x='Securities Account',y='Income',hue ='Personal Loan',data=data,color='red')

# %% [markdown]
# **Observation:** Chances of Customer who has high Income and No securities Account may purchase the loan also if customers has securities account with the bank could purchase the loan.

# %%
#Visualizing boxplot between Mortgage and Education.
sns.boxplot(x='Education',y='Mortgage',hue ='Personal Loan',data=data,color='yellow')

# %% [markdown]
# **Observation:** Customer who

# %%
#Visualizing boxplot between Income and Family.
sns.boxplot(x='Family',y='Income',hue ='Personal Loan',data=data)

# %% [markdown]
# **Observation:**
# 1. Customers whose income is high and even if the family size of customers is more may purchase the loan.
# 2.Customers whose income is low may not purchase the loan and here family size would not matter.

# %%
#Visualizing Countplot of Securities Account.
sns.countplot(x='Securities Account',hue='Personal Loan',data=data);

# %% [markdown]
# **Observation:** Customers who didn't have Securities Account with the bank has very less possibilites of purchasing the loan.

# %%
#Visualizing countplot of Education
sns.countplot(x='Education',hue='Personal Loan',data=data);

# %% [markdown]
# **Observation:**
# Customers with professional background can purchase the loan as compared to other.

# %%
#Plotting Pie-Chart of Personal Loan to visualize the percentage
DF=pd.DataFrame(data['Personal Loan'].value_counts()).reset_index()
DF.columns=['Labels','Personal Loan']
fig1,ax1=plt.subplots(figsize=(10,8))
explode=(0,0.15)
ax1.pie(DF['Personal Loan'],explode=explode,autopct='%1.1f%%',shadow=True,startangle=70)
ax1.axis('equal')
plt.title('Personal Loan Percentage')
plt.show()

# %% [markdown]
# **Observation:** From above Pie-Chart,Only 9.6% approved for personal loan

# %%
#Plotting heatmap and visualizing correlation between variables.
fig,ax = plt.subplots(figsize=(15,10))
sns.heatmap(data.corr(),cmap='plasma',annot=True);

    #Income and CCAvg is moderately correlated.
    #Age and Experience is highly correlated

# %% [markdown]
# **Observation:** From above heatmap, CCAvg and Income are correlated.

# %%
sns.pairplot(data)

# %% [markdown]
# **Observation:**
#
# 1. Age Feature is normally distributed with majority of customers falling between 30 years and 60 years of age.We can confirm this by looking at the describe statement above,which shows mean is almost equal to median.
# 2. Income is positively skewed. Majority of the customers have income between 45K and 55K. We can confirm this by saying the mean is greater than the median
# 3. CCAvg is also a positively skewed variable and average spending is between 0K to 10K and majority spends less than 2.5K
# 4. Mortgage 70% of the individuals have a mortgage of less than 40K. However the max value is 635K
# 5. The variables family and education are ordinal variables. The distribution of families is evenly distributes

# %% [markdown]
# **4. Scaling Data**

# %%
data.head()
# Out:
#         Age    Income    Family  ...  CD Account  Online  CreditCard
# 0  0.045455  0.189815  1.000000  ...           0       0           0
# 1  0.500000  0.120370  0.666667  ...           0       0           0
# 2  0.363636  0.013889  0.000000  ...           0       0           0
# 3  0.272727  0.425926  0.000000  ...           0       0           0
# 4  0.272727  0.171296  1.000000  ...           0       0           1
#
# [5 rows x 11 columns]

# %%
#Importing MinMaxScaler for scaling features.
from sklearn.preprocessing import MinMaxScaler

# %%
#Scaling Age,Income,Family,CCavg,Eduaction,Mortgage using MinMaxScaler to given range.
col_scaling = ['Age', 'Income', 'Family', 'CCAvg', 'Education', 'Mortgage']

for column in col_scaling:
    scaler = MinMaxScaler()
    data[column] = scaler.fit_transform(data[column].values.reshape(-1, 1))

# %%
data.head()
# Out:
#         Age    Income    Family  ...  CD Account  Online  CreditCard
# 0  0.045455  0.189815  1.000000  ...           0       0           0
# 1  0.500000  0.120370  0.666667  ...           0       0           0
# 2  0.363636  0.013889  0.000000  ...           0       0           0
# 3  0.272727  0.425926  0.000000  ...           0       0           0
# 4  0.272727  0.171296  1.000000  ...           0       0           1
#
# [5 rows x 11 columns]

# %% [markdown]
# **Observation:** After Scaling the Features,all values are in the range of (0,1) and now we are ready to split our data.

# %% [markdown]
# **5. Model Development**

# %%
#Assigning Feature Variables and Target Variable.
X = data.drop(['Personal Loan'], axis=1)
y = data['Personal Loan'].values

X.shape, y.shape
# Out:
# ((5000, 10), (5000,))

# %%
#Importing train_test_split into training and testing set.
#Spliting the data into training and test data in 70:30 ratio respectively.
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify= y,random_state=0)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((3500, 10), (1500, 10), (3500,), (1500,))

# %% [markdown]
# **5.1 (MODEL-1) LOGISTIC REGRESSION**

# %%
#Importing LogisticRegression model.
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression(C=1.0, max_iter=200)      #Iterating it 200times.
log_reg.fit(X_train, y_train)                          #fitting our model.
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=200,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
class_names = ['Wont Take Loan','Take Loan']      #Assigning classnames for better understanding.

# %%
#Importing required metrics for evaluating the performance.
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score

# %%
print('Logistic Regression Results: ')

train_score = log_reg.score(X_train, y_train)
print('Training Accuracy:', train_score.round(5))
test_score = log_reg.score(X_test, y_test)
print('Testing Accuracy:', test_score.round(5))

y_pred_logi = log_reg.predict(X_test)

precision_logi = precision_score(y_test, y_pred_logi, labels=class_names).round(3)
print('Precision:', precision_logi)
recall_logi = recall_score(y_test, y_pred_logi).round(3)
print('Recall:', recall_logi)
f1_logi = f1_score(y_test, y_pred_logi).round(3)
print('f1 Score:', f1_logi)
model_f1_score.append(f1_logi)
acc_logi = accuracy_score(y_test, y_pred_logi)
print('Accuracy Score:', acc_logi)
model_accuracy_score.append(acc_logi)
# Out:
# Logistic Regression Resuts:
# Training Accuracy: 0.95057
# Testing Accuracy: 0.94867
# Precision: 0.87
# Recall: 0.55
# f1 Score: 0.67
# Accuracy Score: 0.9486666666666667

# %%
from sklearn.metrics import confusion_matrix 
cm= confusion_matrix(y_test, y_pred_logi)           #Plotting Confusion Matrix
cm
# Out:
# array([[1344,   12],
#        [  65,   79]])

# %% [markdown]
# **Observation:** Accuracy Score for Logistic Regression is quite good.

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      1356
#            1       0.87      0.88      0.88       144
#
#     accuracy                           0.98      1500
#    macro avg       0.93      0.93      0.93      1500
# weighted avg       0.98      0.98      0.98      1500

# %%
from sklearn.metrics import plot_confusion_matrix, plot_roc_curve, plot_precision_recall_curve

plot_confusion_matrix(log_reg, X_test, y_test, display_labels=class_names,values_format ='d')
plt.title('Confusion Matrix for Logistic Regression')          #Plotting Confusion matrix to get proper knowledge

plot_roc_curve(log_reg, X_test, y_test)
plt.title('ROC Curve for Logistic Regression')                  

plot_precision_recall_curve(log_reg, X_test, y_test)
plt.title('Precision-Recall Curve for Logistic Regression')
# Out:
# Text(0.5, 1.0, 'Precision-Recall Curve for Logistic Regression')

# %% [markdown]
# **Observation:** AUC Score for Logisitic Regression is 0.96

# %% [markdown]
# **5.2 (MODEL-2) DECISIONTREECLASSIFIER**

# %%
from sklearn.tree import DecisionTreeClassifier       #Importing DecisionTreeClassifier for the model.

classifier= DecisionTreeClassifier(criterion='entropy', random_state=0,max_depth=7)  
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=7, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=0, splitter='best')

# %%
print('Decision Classifier Resuts: ')

train_score = classifier.score(X_train, y_train)
print('Training Accuracy:', train_score.round(2))
test_score = classifier.score(X_test, y_test)
print('Testing Accuracy:', test_score.round(2))

y_pred_dec = classifier.predict(X_test)

precision_dec = precision_score(y_test, y_pred_dec, labels=class_names).round(2)
print('Precision:', precision_dec)
recall_dec = recall_score(y_test, y_pred_dec).round(2)
print('Recall:', recall_dec)
f1_dec = f1_score(y_test, y_pred_rf).round(2)
print('f1 Score:', f1_dec)
model_f1_score.append(f1_dec)
acc_dec = accuracy_score(y_test, y_pred_dec)
print('Accuracy Score:', acc_dec)
model_accuracy_score.append(acc_dec)
# Out:
# Decision Classifier Resuts:
# Training Accuracy: 0.99
# Testing Accuracy: 0.98
# Precision: 0.87
# Recall: 0.88
# f1 Score: 0.91
# Accuracy Score: 0.976

# %% [markdown]
# **Observation:** Accuracy Score of Decision Tree is better than Logistic Regression i.e 0.976,which means Decision Tree is better predictor model than logistic regression.

# %%
from sklearn.metrics import confusion_matrix       #Plotting Confusion Matrix
cm= confusion_matrix(y_test, y_pred_dec) 
cm
# Out:
# array([[1337,   19],
#        [  17,  127]])

# %% [markdown]
# **Observation:**

# %%
plot_confusion_matrix(classifier, X_test, y_test, display_labels=class_names,values_format='d')
plt.title('Confusion Matrix for DecisionClassifier')

plot_roc_curve(classifier, X_test, y_test)
plt.title('ROC Curve for DecisionClassifier')

plot_precision_recall_curve(classifier, X_test, y_test)
plt.title('Precision-Recall DecisionClassifier')
# Out:
# Text(0.5, 1.0, 'Precision-Recall DecisionClassifier')

# %% [markdown]
# **Observation:** AUC Score for DecisionTree Classifier is 0.96

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred_dec))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      1356
#            1       0.87      0.88      0.88       144
#
#     accuracy                           0.98      1500
#    macro avg       0.93      0.93      0.93      1500
# weighted avg       0.98      0.98      0.98      1500

# %% [markdown]
# **5.3 (MODEL-3) RANDOMFORESTCLASSIFIER**

# %%
from sklearn.ensemble import RandomForestClassifier 

ranfor_class = RandomForestClassifier(n_estimators=300, max_depth=5,n_jobs=-1 )
ranfor_class.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=5, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=300,
#                        n_jobs=-1, oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)

# %%
print('Random Decision Classifier Resuts: ')

train_score = ranfor_class.score(X_train, y_train)
print('Training Accuracy:', train_score.round(5))
test_score = ranfor_class.score(X_test, y_test)
print('Testing Accuracy:', test_score.round(5))

y_pred_rf = ranfor_class.predict(X_test)

precision_rf = precision_score(y_test, y_pred_rf, labels=class_names).round(2)
print('Precision:', precision_rf)
recall_rf = recall_score(y_test, y_pred_rf).round(2)
print('Recall:', recall_rf)
f1_rf = f1_score(y_test, y_pred_rf).round(2)
print('f1 Score:', f1_rf)
model_f1_score.append(f1_rf)
acc_rf = accuracy_score(y_test, y_pred_rf)
print('Accuracy Score:', acc_rf)
model_accuracy_score.append(acc_rf)
print("MAE:",metrics.mean_absolute_error(y_test,y_pred))
# Out:
# Random Decision Classifier Resuts:
# Training Accuracy: 0.986
# Testing Accuracy: 0.98467
# Precision: 1.0
# Recall: 0.84
# f1 Score: 0.91
# Accuracy Score: 0.9846666666666667
# MAE: 0.024

# %% [markdown]
# **Observation:** Accuracy Score of Random Forest is much good than Decision Tree and Logistic Regression Model i.e 0.9846.

# %%
from sklearn.metrics import confusion_matrix 
cm= confusion_matrix(y_test, y_pred_rf)             #Plotting Confusion Matrix
cm
# Out:
# array([[1356,    0],
#        [  23,  121]])

# %%
plot_confusion_matrix(ranfor_class, X_test, y_test, display_labels=class_names,values_format='d')
plt.title('Confusion Matrix for Random Forest Classifier')

plot_roc_curve(ranfor_class, X_test, y_test)
plt.title('ROC Curve for Random Forest Classifier')

plot_precision_recall_curve(ranfor_class, X_test, y_test)
plt.title('Precision-Recall Random Forest Classifier')
# Out:
# Text(0.5, 1.0, 'Precision-Recall Random Forest Classifier')

# %% [markdown]
# **Observation:** AUC Score for RandomForest Classifier is 0.99

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1356
#            1       1.00      0.84      0.91       144
#
#     accuracy                           0.98      1500
#    macro avg       0.99      0.92      0.95      1500
# weighted avg       0.98      0.98      0.98      1500

# %% [markdown]
# **5.4 (MODEL-4) NAVIE BAYES**

# %%
from sklearn.naive_bayes import GaussianNB

naive_model = GaussianNB()
naive_model.fit(X_train, y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
print(' Navie Bayes Classifier Resuts: ')

train_score = naive_model.score(X_train, y_train)
print('Training Accuracy:', train_score.round(2))
test_score = naive_model.score(X_test, y_test)
print('Testing Accuracy:', test_score.round(2))

y_pred_nb = naive_model.predict(X_test)

precision_nb = precision_score(y_test, y_pred_nb, labels=class_names).round(2)
print('Precision:', precision_nb)
recall_nb = recall_score(y_test, y_pred_nb).round(2)
print('Recall:', recall_nb)
f1_nb = f1_score(y_test, y_pred_nb).round(2)
print('f1 Score:', f1_nb)
model_f1_score.append(f1_nb)
acc_nb = accuracy_score(y_test, y_pred_nb)
print('Accuracy Score:', acc_nb)
model_accuracy_score.append(acc_nb)
print("MAE:",metrics.mean_absolute_error(y_test,y_pred))
# Out:
#  Navie Bayes Classifier Resuts:
# Training Accuracy: 0.88
# Testing Accuracy: 0.89
# Precision: 0.43
# Recall: 0.6
# f1 Score: 0.5
# Accuracy Score: 0.8866666666666667
# MAE: 0.024

# %% [markdown]
# **Observation: Accuracy Score of Naive Bayes is not good compared to Random Forest,Decision Treeand Logistic Regression.

# %%
from sklearn.metrics import confusion_matrix 
cm= confusion_matrix(y_test, y_pred_nb)          #Plotting Confusion Matrix
cm
# Out:
# array([[1244,  112],
#        [  58,   86]])

# %%
plot_confusion_matrix(naive_model, X_test, y_test, display_labels=class_names,values_format='d')
plt.title('Confusion Matrix for Naive Bayes Classifier')

plot_roc_curve(naive_model, X_test, y_test)
plt.title('ROC Curve for Naive Bayes Classifier')

plot_precision_recall_curve(naive_model, X_test, y_test)
plt.title('Precision-Recall Naive Bayes Classifier')
# Out:
# Text(0.5, 1.0, 'Precision-Recall Naive Bayes Classifier')

# %% [markdown]
# **Observation:** AUC Score for Naive Bayes is 0.93

# %% [markdown]
# **5.5 (MODEL-5) KNNCLASSIFIER**

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=3)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %%
print(' KNN Classifier Resuts: ')

train_score = knn.score(X_train, y_train)
print('Training Accuracy:', train_score.round(2))
test_score = knn.score(X_test, y_test)
print('Testing Accuracy:', test_score.round(2))

y_pred_knn = knn.predict(X_test)

precision_knn = precision_score(y_test, y_pred_knn, labels=class_names).round(2)
print('Precision:', precision_knn)
recall_knn = recall_score(y_test, y_pred_knn).round(2)
print('Recall:', recall_knn)
f1_knn = f1_score(y_test, y_pred_knn).round(2)
print('f1 Score:', f1_knn)
model_f1_score.append(f1_knn)
acc_knn = accuracy_score(y_test, y_pred_knn)
print('Accuracy Score:', acc_knn)
model_f1_score.append(acc_knn)
print("MAE:",metrics.mean_absolute_error(y_test,y_pred))
print("R2 Score:",metrics.r2_score(y_test,y_pred))
# Out:
#  KNN Classifier Resuts:
# Training Accuracy: 0.98
# Testing Accuracy: 0.97
# Precision: 0.93
# Recall: 0.69
# f1 Score: 0.79
# Accuracy Score: 0.9653333333333334
# MAE: 0.024
# R2 Score: 0.7234513274336283

# %% [markdown]
# **Observation:** Accuracy Score of KNN Classifier is good comapred to Naive Bayes and Logistic Regression.But,it is not good compared to Random Forest and Decision Tree.

# %%
from sklearn.metrics import confusion_matrix 
cm= confusion_matrix(y_test, y_pred_knn)          #Plotting Confusion Matrix
cm
# Out:
# array([[1349,    7],
#        [  45,   99]])

# %%
plot_confusion_matrix(knn, X_test, y_test, display_labels=class_names,values_format='d')
plt.title('Confusion Matrix for KNN Classifier')

plot_roc_curve(knn, X_test, y_test)
plt.title('ROC Curve for KNN Classifier')

plot_precision_recall_curve(knn, X_test, y_test)
plt.title('Precision-Recall KNN Classifier')
# Out:
# Text(0.5, 1.0, 'Precision-Recall KNN Classifier')

# %% [markdown]
# **Observation:** AUC Score for KNN Classifier is 0.94

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      1356
#            1       0.93      0.69      0.79       144
#
#     accuracy                           0.97      1500
#    macro avg       0.95      0.84      0.89      1500
# weighted avg       0.96      0.97      0.96      1500

# %% [markdown]
# **5.6 (MODEL-6) SVM**

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

clf = SVC(kernel='linear')
clf.fit(X_train,y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
print('SVM Resuts: ')

train_score = clf.score(X_train, y_train)
print('Training Accuracy:', train_score.round(4))
test_score = clf.score(X_test, y_test)
print('Testing Accuracy:', test_score.round(4))

y_pred_svm = clf.predict(X_test)

precision_svm = precision_score(y_test, y_pred_svm, labels=class_names).round(2)
print('Precision:', precision_dec)
recall_svm = recall_score(y_test, y_pred_svm).round(2)
print('Recall:', recall_svm)
f1_svm = f1_score(y_test, y_pred_svm).round(2)
print('f1 Score:', f1_svm)
model_f1_score.append(f1_svm)
acc_svm = accuracy_score(y_test, y_pred_svm)
print('Accuracy Score:', acc_svm)
model_f1_score.append(acc_svm)
print("MAE:",metrics.mean_absolute_error(y_test,y_pred))
# Out:
# SVM Resuts:
# Training Accuracy: 0.9546
# Testing Accuracy: 0.9473
# Precision: 0.87
# Recall: 0.54
# f1 Score: 0.66
# Accuracy Score: 0.9473333333333334
# MAE: 0.024

# %% [markdown]
# **Observation:** Accuracy Score of SVM is good than Naive Bayes but not comparable to KNN,Random  Forest,Decision Tree,Logistic Regression.

# %%
from sklearn.metrics import confusion_matrix 
cm= confusion_matrix(y_test, y_pred_svm)             #Plotting Confusion Matrix
cm
# Out:
# array([[1343,   13],
#        [  66,   78]])

# %%
plot_confusion_matrix(clf, X_test, y_test, display_labels=class_names,values_format='d')
plt.title('Confusion Matrix for SVM Model')

plot_roc_curve(clf, X_test, y_test)
plt.title('ROC Curve for SVM Model')

plot_precision_recall_curve(clf, X_test, y_test)
plt.title('Precision-Recall SVM Model')
# Out:
# Text(0.5, 1.0, 'Precision-Recall SVM Model')

# %% [markdown]
# **Observation:** AUC Score for SVM is 0.95

# %%
print(classification_report(y_test,y_pred_svm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      1356
#            1       0.86      0.54      0.66       144
#
#     accuracy                           0.95      1500
#    macro avg       0.91      0.77      0.82      1500
# weighted avg       0.94      0.95      0.94      1500

# %% [markdown]
# **5.7 (MODEL-7) XGBOOST CLASSIFIER**

# %%
from xgboost import XGBClassifier

# %%
from xgboost import XGBClassifier

xgb = XGBClassifier()
xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
print('XGBoost Resuts: ')

train_score = xgb.score(X_train, y_train)
print('Training Accuracy:', train_score.round(5))
test_score = xgb.score(X_test, y_test)
print('Testing Accuracy:', test_score.round(5))

y_pred_xgb = xgb.predict(X_test)

precision_xgb = precision_score(y_test, y_pred_xgb, labels=class_names).round(2)
print('Precision:', precision_xgb)
recall_xgb = recall_score(y_test, y_pred_xgb).round(2)
print('Recall:', recall_xgb)
f1_xgb = f1_score(y_test, y_pred_xgb).round(2)
print('f1 Score:', f1_xgb)
model_f1_score.append(f1_xgb)
acc_xgb = accuracy_score(y_test, y_pred_xgb)
print('Accuracy Score:', acc_xgb)
model_f1_score.append(acc_xgb)
print("MAE:",metrics.mean_absolute_error(y_test,y_pred))
# Out:
# XGBoost Resuts:
# Training Accuracy: 0.992
# Testing Accuracy: 0.98467
# Precision: 0.93
# Recall: 0.91
# f1 Score: 0.92
# Accuracy Score: 0.9846666666666667
# MAE: 0.024

# %% [markdown]
# **Observation:** Accuracy Score of XGBoost Classifier is much good comparable to other models but not as good as Random Forest if we also compare with other scores/parameters.

# %%
from sklearn.metrics import confusion_matrix 
cm= confusion_matrix(y_test, y_pred_xgb)     #Plotting Confusion Matrix
cm
# Out:
# array([[1346,   10],
#        [  13,  131]])

# %%
plot_confusion_matrix(xgb, X_test, y_test, display_labels=class_names,values_format='d')
plt.title('Confusion Matrix for XGBoost Classifier')

plot_roc_curve(xgb, X_test, y_test)
plt.title('ROC Curve for XGBoost Classifier')

plot_precision_recall_curve(xgb, X_test, y_test)
plt.title('Precision-Recall XGBoost Classifier')
# Out:
# Text(0.5, 1.0, 'Precision-Recall XGBoost Classifier')

# %% [markdown]
# **Observation:**
#
# 1.AUC Score for XGBoost Classifier is 1.00

# %% [markdown]
# **7. Analyzing all Models Results**

# %%
from sklearn import model_selection
seed = 7
models = []
models.append(('LR', LogisticRegression()))
models.append(('DTC', DecisionTreeClassifier()))
models.append(('RFC', RandomForestClassifier()))
models.append(('NB', GaussianNB()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('SVM', SVC()))
models.append(('XGB',XGBClassifier()))

# evaluate each model in turn
results = []
names = []
scoring = 'accuracy'
for name, model in models:
	kfold = model_selection.KFold(n_splits=10, random_state=seed,shuffle=True)
	cv_results = model_selection.cross_val_score(model, X, y, cv=kfold, scoring=scoring)
	results.append(cv_results)
	names.append(name)
	msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
	print(msg)
# boxplot algorithm comparison
fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()
# Out:
# LR: 0.950800 (0.010438)
# DTC: 0.985200 (0.006400)
# RFC: 0.988000 (0.004099)
# NB: 0.883200 (0.008304)
# KNN: 0.962200 (0.009816)
# SVM: 0.975600 (0.006312)
# XGB: 0.986600 (0.003353)

# %% [markdown]
# **8. CONCLUSION**

# %% [markdown]
# 1. The aim of the bank is to convert there liability customers into loan customers. They want to set up a marketing campaign; hence, they need information about the connection between the variables given in the data. Six classification algorithms were used in this study. From the above graph , it seems like RandomForest Classifier is best suited for the model.

# %% [markdown]
# 2. ROC curve is plotted with TPR against the FPR where TPR is on
# y-axis and FPR is on the x-axis
#
#    ROC is a probability curve and AUC represents degree or
# measure of separability. It tells how much model is capable of distinguishing between classes.
#
#    Higher the AUC, better the model is at distinguishing between a customer buying personal Loan and Not buying Personal Loan.
#
#    From six algorithms we evaluated that AUC Score of RandomForest Classifier has 0.99 .
#
#    Now,if we compare this 2 model more accuratley by anaylzing precision,recall,accuracy,f1Score  Random Classifier can almost  give best result.
